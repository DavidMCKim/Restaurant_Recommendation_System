# %%
import pandas as pd
import numpy as np
from selenium import webdriver
import time
from bs4 import BeautifulSoup 
from tqdm import tqdm
import requests
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
import re

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %% [markdown]
# ## 지역별 num 불러오기

# %%
aewol_matzip_num = pd.read_csv('aewol_matzip_num.csv', index_col=0) # 애월읍
hanlim_matzip_num = pd.read_csv('hanlim_matzip_num.csv', index_col=0) # 한림읍
hangyeon_matzip_num = pd.read_csv('hangyeon_matzip_num.csv', index_col=0) # 한경면
daejeong_matzip_num = pd.read_csv('daejeong_matzip_num.csv', index_col=0) # 대정읍
anduck_matzip_num = pd.read_csv('anduck_matzip_num.csv', index_col=0) # 안덕면

# %%
matzip_type = []
matzip_name = []
matzip_addr = []
matzip_score = []
matzip_phone = []

# %%
def info_crawl(rocalname):
    
    # 빈 리스트 생성
    matzip_type = []
    matzip_name = []
    matzip_addr = []
    matzip_score = []
    matzip_phone = []
    print(len(matzip_type))
    driver = webdriver.Chrome('/Users/mckimair/chromedriver')
    
    for i in tqdm(globals()[f'{rocalname}_matzip_num']['num']):
        new_url = f'https://pcmap.place.naver.com/accommodation/{i}/home?'
        driver.get(new_url)
        html = driver.page_source
        soup = BeautifulSoup(html, 'lxml')
        time.sleep(1)
        name = soup.find('span',{'class':'_3XamX'})
        style = soup.find('span',{'class':'_3ocDE'})
        addr = soup.find('span',{'class':'_2yqUQ'})
        score = soup.find('span',{'class':'_1Y6hi _1A8_M'})
        
        try :
            matzip_type.append(style.text)     ## 캠핑장 유형
        except:
            matzip_type.append('none')
            
        try:
            matzip_name.append(name.text)      ## 캠핑장 이름
        except:
            matzip_name.append('none')
        
        try:
            matzip_addr.append(addr.text)      ## 캠핑장 주소
        except:
            matzip_addr.append('none')
            
        try:
            matzip_score.append(score.em.text) ## 캠핑장 평균별점
        except:
            matzip_score.append('none')
        ## 전화번호
        try:     
            phone_num = soup.find('span',{'class':'_3ZA0S'})
            matzip_phone.append(phone_num.text)        
        except:
            matzip_phone.append('none')
    driver.quit()
    
    globals()[f'{rocalname}_matzip_dict'] = {'Num':globals()[f'{rocalname}_matzip_num']['num'].to_list(), 'Type':matzip_type, 'Name':matzip_name, 'Address':matzip_addr, 'Score':matzip_score, 'Phone':matzip_phone}
    globals()[f'{rocalname}_matzip_info_df'] = pd.DataFrame(globals()[f'{rocalname}_matzip_dict'])
    
    globals()[f'{rocalname}_matzip_info_df'].to_csv(f'{rocalname}_matzip__info_df.csv')

# %%
# len(aewol_matzip_num)
len(matzip_type)
len(matzip_name)
len(matzip_addr)
len(matzip_score)
len(matzip_phone)
# Out:
# 600
# 600
# 600
# 600
# 600

# %%
jeju_rocal_name = ['aewol','hanlim','hangyeon','daejeong','anduck']

# %%
len(matzip_type)
len(matzip_name)
len(matzip_addr)
len(matzip_score)
len(matzip_phone)
# Out:
# 600
# 600
# 600
# 600
# 600

# %%
hangyeon

# %%
hangyeon_matzip_dict = {'Num':hangyeon_matzip_num['num'].to_list(), 'Type':matzip_type[300:], 'Name':matzip_name[300:], 'Address':matzip_addr[300:], 'Score':matzip_score[300:], 'Phone':matzip_phone[300:]}
hangyeon_matzip_info_df = pd.DataFrame(hangyeon_matzip_dict)
hangyeon_matzip_info_df.to_csv('hangyeon_matzip__info_df.csv')

# %%
for name in tqdm(jeju_rocal_name[:1]):
#     globals()[f'{name}_matzip_num'] = pd.read_csv(f'{name}_matzip_num.csv')
    info_crawl(name)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          |
#  95%|█████████▍| 284/300 [10:52<00:36,  2.27s/it]
#  95%|█████████▌| 285/300 [10:54<00:34,  2.31s/it]
#  95%|█████████▌| 286/300 [10:56<00:32,  2.32s/it]
#  96%|█████████▌| 287/300 [10:59<00:29,  2.27s/it]
#  96%|█████████▌| 288/300 [11:01<00:26,  2.18s/it]
#  96%|█████████▋| 289/300 [11:03<00:25,  2.30s/it]
#  97%|█████████▋| 290/300 [11:05<00:22,  2.28s/it]
#  97%|█████████▋| 291/300 [11:07<00:19,  2.19s/it]
#  97%|█████████▋| 292/300 [11:10<00:17,  2.18s/it]
#  98%|█████████▊| 293/300 [11:12<00:15,  2.20s/it]
#  98%|█████████▊| 294/300 [11:14<00:13,  2.21s/it]
#  98%|█████████▊| 295/300 [11:16<00:11,  2.25s/it]
#  99%|█████████▊| 296/300 [11:19<00:09,  2.36s/it]
#  99%|█████████▉| 297/300 [11:21<00:06,  2.31s/it]
#  99%|█████████▉| 298/300 [11:24<00:04,  2.45s/it]
# 100%|█████████▉| 299/300 [11:27<00:02,  2.49s/it]
# 100%|██████████| 300/300 [11:29<00:00,  2.30s/it]
# 100%|██████████| 1/1 [11:33<00:00, 693.92s/it]

# %%
for name in jeju_rocal_name:
    globals()[f'{name}_matzip_type'] = []
    globals()[f'{name}_matzip_name'] = []
    globals()[f'{name}_matzip_addr'] = []
    globals()[f'{name}_matzip_score'] = []
    globals()[f'{name}_matzip_phone'] = []

# %%
def info_crawl(rocalname):
    driver = webdriver.Chrome('/Users/mckimair/chromedriver')
    for i in tqdm(globals()[f'{rocalname}_matzip_num']['num']):
        new_url = f'https://pcmap.place.naver.com/accommodation/{i}/home?'
        driver.get(new_url)
        html = driver.page_source
        soup = BeautifulSoup(html, 'lxml')
        time.sleep(1)
        name = soup.find('span',{'class':'_3XamX'})
        style = soup.find('span',{'class':'_3ocDE'})
        addr = soup.find('span',{'class':'_2yqUQ'})
        score = soup.find('span',{'class':'_1Y6hi _1A8_M'})
        
        try :
            globals()[f'{name}_matzip_type'].append(style.text)     ## 캠핑장 유형
            globals()[f'{name}_matzip_name'].append(name.text)      ## 캠핑장 이름
            globals()[f'{name}_matzip_addr'].append(addr.text)      ## 캠핑장 주소
            globals()[f'{name}_matzip_score'].append(score.em.text) ## 캠핑장 평균별점
        except:
            globals()[f'{name}_matzip_score'].append('none')
        ## 전화번호
        try:     
            phone_num = soup.find('span',{'class':'_3ZA0S'})
            globals()[f'{name}_matzip_phone'].append(phone_num.text)        
        except:
            globals()[f'{name}_matzip_phone'].append('none')
    driver.quit()
    
    globals()[f'{rocalname}_matzip_dict'] = {'Num':globals()[f'{rocalname}_matzip_num']['num'].to_list(), 'Type':globals()[f'{rocalname}_matzip_type'], 'Name':globals()[f'{rocalname}_matzip_name'], 'Address':globals()[f'{rocalname}_matzip_addr'], 'Score':globals()[f'{rocalname}_matzip_score'], 'Phone':globals()[f'{rocalname}_matzip_phone']}
    globals()[f'{rocalname}_matzip_info_df'] = pd.DataFrame(globals()[f'{rocalname}_matzip_dict'])
    
    globals()[f'{rocalname}_matzip_info_df'].to_csv(f'{rocalname}_matzip__info_df.csv')

# %% [markdown]
# ## 리뷰데이터 크롤링

# %%
def review_crawl():
    driver = webdriver.Chrome('/Users/mckimair/chromedriver')
    
    for i in range(len(gyeonggi_camp_info)):

        review_url = 'https://pcmap.place.naver.com/accommodation/{}/review/visitor?'.format(gyeonggi_camp_info['Num'][i])
    #     print(review_url)
        try:
            print('======================================================')
            print(str(i+1)+'번째 캠핑장')

            # 캠핑장 리뷰 개별 url 접속
            driver.get(review_url)
            time.sleep(2) 

            while True:
                try:
                    # END 키를 눌러서 페이지 제일 하단으로 이동
                    driver.find_element_by_tag_name('body').send_keys(Keys.END)
                    time.sleep(2)
                    # 더보기 버튼 클릭
                    
                    driver.find_element_by_xpath('//*[@id="app-root"]/div/div/div[2]/div[5]/div[4]/div[4]/div[2]/a').click()
                    time.sleep(2)
                    # END 키를 눌러서 페이지 제일 하단으로 이동
                    driver.find_element_by_tag_name('body').send_keys(Keys.END)
                    time.sleep(1)

                except NoSuchElementException:
                    print('-더보기 버튼 모두 클릭 완료-')
                    break

            # 파싱
            html = driver.page_source
            soup = BeautifulSoup(html, 'lxml')
            time.sleep(1)

            # 캠핑장 구분
            camping_site_name = gyeonggi_camp_info['Name'][i]
            print('사업장명 : '+ camping_site_name)

            try:
                all_review = soup.find_all('div', attrs = {'class':'_1Z_GL'})
                review_num = len(all_review) # 특정 캠핑의 리뷰 총 개수
                print('리뷰 총 개수 : '+ str(review_num))

                print('----------------------------------------------')

                for review in range(review_num):
                    ## 캠핑장 고유 넘버 
                    camping_num_list.append(gyeonggi_camp_info["Num"][i])

                    ## 캠핑장주소
                    camping_addr_list.append(gyeonggi_camp_info["Address"][i])

                    ## 캠핑장 이름
                    camping_name_list.append(camping_site_name)
                    print(camping_site_name)

                    ## user ID
                    user = soup.find_all('div',{'class':'hbo4A'})
                    print('{}번째 user:'.format(review+1),user[review].text)
                    user_id_list.append(user[review].text)

                    ## rating(사용자가 이 캠핑장에 준 별점)
                    rating = all_review[review].find('span', attrs = {'class':'_2tObC'}).text
                    print('rating = '+rating)
                    rating_list.append(rating)

                    ## 사용자의 평균 별점
                    avg_rating = soup.find_all('div',{'class':'ql4ZC'})
                    print('avg_rating ='+avg_rating[review].text)
                    avg_rating_list.append(avg_rating[review].text)

                    # 주의!!! 사진 리뷰 유무에 따라 날짜 파싱코드 다름
                    # ('span', attrs = {'class':'_3WqoL'})
                    # 사진 없는 경우 : 총 6개 중 4번째
                    # 사진 있는 경우 : 총 5개 중 3번째

                    ## date
                    # 사진 리뷰 없음
                    if len(all_review[review].find_all('span', attrs = {'class':'_3WqoL'})) == 5:
                        date = all_review[review].find_all('span', attrs = {'class':'_3WqoL'})[2].text
                    elif len(all_review[review].find_all('span', attrs = {'class':'_3WqoL'})) == 6:
                        date = all_review[review].find_all('span', attrs = {'class':'_3WqoL'})[3].text
                    else:
                        date = ""
                    print('date = '+date)
                    date_list.append(date)

                    ## count 방문횟수
                    if len(all_review[review].find_all('span', attrs = {'class':'_3WqoL'})) == 5:
                        count = all_review[review].find_all('span', attrs = {'class':'_3WqoL'})[3].text
                    elif len(all_review[review].find_all('span', attrs = {'class':'_3WqoL'})) == 6:
                        count = all_review[review].find_all('span', attrs = {'class':'_3WqoL'})[4].text
                    else:
                        count = ""
                    print('방문횟수 = '+count)
                    count_list.append(count)                

                    ## review 내용
                    try: 
                        review_content = all_review[review].find('span', attrs = {'class':'WoYOw'}).text
                    except: # 리뷰가 없다면
                        review_content = ""
                    print('리뷰 내용 : '+review_content)
                    review_list.append(review_content)                    

                    print('\n\n')

            except Exception as total_review_err:
                none_review = "네이버 리뷰 0개"
                print(none_review)   


        except Exception as err:
            print(err)
            error_list = '{}행 에러 : {}'.format(i,err)
            error.append(error_list)
            rating_list.append(' ')
            avg_rating_list.append(' ')
            review_list.append(' ')

    driver.quit()

# %%
aewol = pd.read_csv('aewol_matzip__info_df.csv', index_col=0)
aewol
# Out:
#             Num    Type        Name                            Address Score  \
# 0    1618248387  카페,디저트        테라도스          제주 제주시 애월읍 애상로 207-2 테라도스  4.84
# 1      19872990      쌈밥  이춘옥원조고등어쌈밥               제주 제주시 애월읍 일주서로 7213  4.62
# 2      37264234   아시아음식        호커센터        제주 제주시 애월읍 애월로11길 25-2 호커센터   4.9
# 3      19872990      쌈밥  이춘옥원조고등어쌈밥               제주 제주시 애월읍 일주서로 7213  4.62
# 4    1903527640    초밥,롤       한라봉스시             제주 제주시 애월읍 애월북서길 54 2층  4.29
# ..          ...     ...         ...                                ...   ...
# 295   186579806  카페,디저트     블라썸1407                제주 제주시 애월읍 고하상로 103  4.39
# 296  1389926669  카페,디저트       본까페애월               제주 제주시 애월읍 애월해안로 177  4.28
# 297  1918412930      한식     풍원 정인국수  제주 제주시 애월읍 유수암평화길 242 요석원 나동 101호  4.15
# 298  1885868678      카페         본카페               제주 제주시 애월읍 애월해안로 179  4.53
# 299  1226182771  카페,디저트      카페 퍼시몬           제주 제주시 애월읍 하소로 611-6 퍼시몬   4.5
#
#               Phone
# 0     010-8565-4162
# 1    0507-1402-9914
# 2    0507-1405-8989
# 3    0507-1402-9914
# 4     070-4566-9001
# ..              ...
# 295    064-799-1407
# 296    064-799-5789
# 297    064-799-8338
# 298   010-4123-8004
# 299   010-8367-7817
#
# [300 rows x 6 columns]

# %%
camping_num   = []  # 캠핑장 고유넘버

camping_type  = []  # 캠핑장 유형 (ex.캠핑,야영장 / 온천,스파 / 카페 등등..)
camping_name  = []  # 캠핑장 이름
camping_addr  = []  # 캠핑장 주소
camping_score = []  # 캠핑장 평균별점
camping_phone = []  # 캠핑장 전화번호
camping_site  = []  # 캠핑장 사이트(site) 
camping_info1 = []  # 캠핑장 부가설명1
camping_info2 = []  # 캠핑장 부가설명2

camping_num_list  = []
camping_addr_list = []
camping_name_list = []
user_id_list      = []
camping_type_list = []
rating_list       = []
avg_rating_list   = []
date_list         = []
review_list       = []
count_list        = []
error             = [] # 에러 내용

# %%
driver = webdriver.Chrome('/Users/mckimair/chromedriver')
    
for i in range(len(aewol)):

    review_url = 'https://pcmap.place.naver.com/accommodation/{}/review/visitor?'.format(aewol['Num'][i])
#     print(review_url)
    try:
        print('======================================================')
        print(str(i+1)+'번째 캠핑장')

        # 캠핑장 리뷰 개별 url 접속
        driver.get(review_url)
        time.sleep(2) 

        while True:
            try:
                # END 키를 눌러서 페이지 제일 하단으로 이동
                driver.find_element_by_tag_name('body').send_keys(Keys.END)
                time.sleep(2)
                # 더보기 버튼 클릭

                driver.find_element_by_xpath('//*[@id="app-root"]/div/div/div[2]/div[5]/div[4]/div[4]/div[2]/a').click()
                time.sleep(2)
                # END 키를 눌러서 페이지 제일 하단으로 이동
                driver.find_element_by_tag_name('body').send_keys(Keys.END)
                time.sleep(1)

            except NoSuchElementException:
                print('-더보기 버튼 모두 클릭 완료-')
                break

        # 파싱
        html = driver.page_source
        soup = BeautifulSoup(html, 'lxml')
        time.sleep(1)

        # 캠핑장 구분
        camping_site_name = aewol['Num'][i]
        print('사업장명 : '+ camping_site_name)

        try:
            all_review = soup.find_all('div', attrs = {'class':'_1Z_GL'})
            review_num = len(all_review) # 특정 캠핑의 리뷰 총 개수
            print('리뷰 총 개수 : '+ str(review_num))

            print('----------------------------------------------')

            for review in range(review_num):
                ## 캠핑장 고유 넘버 
                camping_num_list.append(aewol['Num'][i])

                ## 캠핑장주소
                camping_addr_list.append(aewol["Address"][i])

                ## 캠핑장 이름
                camping_name_list.append(camping_site_name)
                print(camping_site_name)

                ## user ID
                user = soup.find_all('div',{'class':'hbo4A'})
                print('{}번째 user:'.format(review+1),user[review].text)
                user_id_list.append(user[review].text)

                ## rating(사용자가 이 캠핑장에 준 별점)
                rating = all_review[review].find('span', attrs = {'class':'_2tObC'}).text
                print('rating = '+rating)
                rating_list.append(rating)

                ## 사용자의 평균 별점
                avg_rating = soup.find_all('div',{'class':'ql4ZC'})
                print('avg_rating ='+avg_rating[review].text)
                avg_rating_list.append(avg_rating[review].text)

                # 주의!!! 사진 리뷰 유무에 따라 날짜 파싱코드 다름
                # ('span', attrs = {'class':'_3WqoL'})
                # 사진 없는 경우 : 총 6개 중 4번째
                # 사진 있는 경우 : 총 5개 중 3번째

                ## date
                # 사진 리뷰 없음
                if len(all_review[review].find_all('span', attrs = {'class':'_3WqoL'})) == 5:
                    date = all_review[review].find_all('span', attrs = {'class':'_3WqoL'})[2].text
                elif len(all_review[review].find_all('span', attrs = {'class':'_3WqoL'})) == 6:
                    date = all_review[review].find_all('span', attrs = {'class':'_3WqoL'})[3].text
                else:
                    date = ""
                print('date = '+date)
                date_list.append(date)

                ## count 방문횟수
                if len(all_review[review].find_all('span', attrs = {'class':'_3WqoL'})) == 5:
                    count = all_review[review].find_all('span', attrs = {'class':'_3WqoL'})[3].text
                elif len(all_review[review].find_all('span', attrs = {'class':'_3WqoL'})) == 6:
                    count = all_review[review].find_all('span', attrs = {'class':'_3WqoL'})[4].text
                else:
                    count = ""
                print('방문횟수 = '+count)
                count_list.append(count)                

                ## review 내용
                try: 
                    review_content = all_review[review].find('span', attrs = {'class':'WoYOw'}).text
                except: # 리뷰가 없다면
                    review_content = ""
                print('리뷰 내용 : '+review_content)
                review_list.append(review_content)                    

                print('\n\n')

        except Exception as total_review_err:
            none_review = "네이버 리뷰 0개"
            print(none_review)   


    except Exception as err:
        print(err)
        error_list = '{}행 에러 : {}'.format(i,err)
        error.append(error_list)
        rating_list.append(' ')
        avg_rating_list.append(' ')
        review_list.append(' ')

driver.quit()
# Out:
# ======================================================
# 1번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 2번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 3번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 4번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 5번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 6번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 7번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 8번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 9번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 10번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 11번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 12번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 13번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 14번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 15번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 16번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 17번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 18번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 19번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 20번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 21번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 22번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 23번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 24번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 25번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 26번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 27번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 28번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 29번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 30번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 31번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 32번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 33번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 34번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 35번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 36번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 37번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 38번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 39번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 40번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 41번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 42번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 43번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 44번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 45번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 46번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 47번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 48번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 49번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 50번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 51번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 52번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 53번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 54번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 55번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 56번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 57번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 58번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 59번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 60번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 61번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 62번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 63번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 64번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 65번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 66번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 67번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 68번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 69번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 70번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 71번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 72번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 73번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 74번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 75번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 76번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 77번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 78번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 79번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 80번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 81번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 82번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 83번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 84번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 85번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 86번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 87번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 88번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 89번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 90번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 91번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 92번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 93번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 94번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 95번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 96번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 97번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 98번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 99번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 100번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 101번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 102번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 103번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 104번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 105번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 106번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 107번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 108번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 109번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 110번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 111번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 112번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 113번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 114번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 115번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 116번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 117번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 118번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 119번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 120번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 121번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 122번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 123번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 124번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 125번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 126번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 127번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 128번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 129번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 130번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 131번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 132번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 133번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 134번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 135번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 136번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 137번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 138번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 139번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 140번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 141번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 142번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 143번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 144번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 145번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 146번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 147번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 148번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 149번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 150번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 151번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 152번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 153번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 154번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 155번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 156번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 157번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 158번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 159번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 160번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 161번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 162번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 163번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 164번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 165번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 166번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 167번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 168번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 169번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 170번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 171번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 172번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 173번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 174번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 175번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 176번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 177번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 178번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 179번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 180번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 181번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 182번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 183번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 184번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 185번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 186번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 187번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 188번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 189번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 190번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 191번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 192번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 193번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 194번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 195번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 196번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 197번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 198번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 199번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 200번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 201번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 202번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 203번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 204번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 205번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 206번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 207번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 208번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 209번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 210번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 211번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 212번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 213번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 214번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 215번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 216번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 217번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 218번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 219번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 220번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 221번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 222번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 223번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 224번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 225번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 226번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 227번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 228번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 229번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 230번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 231번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 232번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 233번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 234번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 235번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 236번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 237번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 238번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 239번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 240번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 241번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 242번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 243번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 244번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 245번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 246번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 247번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 248번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 249번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 250번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 251번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 252번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 253번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 254번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 255번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 256번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 257번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 258번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 259번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 260번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 261번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 262번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 263번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 264번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 265번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 266번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 267번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 268번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 269번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 270번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 271번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 272번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 273번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 274번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 275번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 276번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 277번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 278번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 279번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 280번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 281번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 282번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 283번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 284번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 285번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 286번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 287번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 288번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 289번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 290번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 291번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 292번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 293번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 294번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 295번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 296번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 297번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 298번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 299번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
#
# ======================================================
# 300번째 캠핑장
# Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)

# %%
driver = webdriver.Chrome('/Users/mckimair/chromedriver')
    
for i in range(len(aewol[:1])):

    review_url = 'https://pcmap.place.naver.com/accommodation/{}/review/visitor?'.format(aewol['Num'][i])
    #     print(review_url)
    try:
        print('======================================================')
    #     print(str(i+1)+'번째 캠핑장')

        # 캠핑장 리뷰 개별 url 접속
        driver.get(review_url)
        time.sleep(2) 

        while True:
            try:
                # END 키를 눌러서 페이지 제일 하단으로 이동
                driver.find_element_by_tag_name('body').send_keys(Keys.END)
                time.sleep(2)
                # 더보기 버튼 클릭

                driver.find_element_by_xpath('//*[@id="app-root"]/div/div/div[2]/div[5]/div[4]/div[4]/div[2]/a').click()
                time.sleep(2)
                # END 키를 눌러서 페이지 제일 하단으로 이동
                driver.find_element_by_tag_name('body').send_keys(Keys.END)
                time.sleep(1)

            except NoSuchElementException:
                print('-더보기 버튼 모두 클릭 완료-')
                break

        # 파싱
        html = driver.page_source
        soup = BeautifulSoup(html, 'lxml')
        time.sleep(1)

        # 캠핑장 구분
        camping_site_name = aewol['Num'][i]
        print('사업장명 : ', camping_site_name)

        try:
            all_review = soup.find_all('li', attrs = {'class':'_3FaRE'})
            review_num = len(all_review) # 특정 캠핑의 리뷰 총 개수
            print('리뷰 총 개수 : '+ str(review_num))

            print('----------------------------------------------')

            for review in range(review_num):
                ## 캠핑장 고유 넘버 
                camping_num_list.append(aewol['Num'][i])

                ## 캠핑장주소
                camping_addr_list.append(aewol["Address"][i])

                ## 캠핑장 이름
                camping_name_list.append(camping_site_name)
                print(camping_site_name)

                ## user ID
                user = soup.find_all('div',{'class':'_16RxQ'})
                print('{}번째 user:'.format(review+1),user[review].text)
                user_id_list.append(user[review].text)

                ## rating(사용자가 이 캠핑장에 준 별점)
                rating = all_review[review].find('span', attrs = {'class':'_2tObC'}).text
                print('rating = ',rating)
                rating_list.append(rating)

                ## 사용자의 평균 별점
                avg_rating = soup.find_all('div',{'class':'ql4ZC'})
                print('avg_rating =',avg_rating[review].text)
                avg_rating_list.append(avg_rating[review].text)

                # 주의!!! 사진 리뷰 유무에 따라 날짜 파싱코드 다름
                # ('span', attrs = {'class':'_3WqoL'})
                # 사진 없는 경우 : 총 6개 중 4번째
                # 사진 있는 경우 : 총 5개 중 3번째

                ## date
                # 사진 리뷰 없음
                if len(all_review[review].find_all('span', attrs = {'class':'_3WqoL'})) == 5:
                    date = all_review[review].find_all('span', attrs = {'class':'_3WqoL'})[2].text
                elif len(all_review[review].find_all('span', attrs = {'class':'_3WqoL'})) == 6:
                    date = all_review[review].find_all('span', attrs = {'class':'_3WqoL'})[3].text
                else:
                    date = ""
                print('date = '+date)
                date_list.append(date)

                ## count 방문횟수
                if len(all_review[review].find_all('span', attrs = {'class':'_3WqoL'})) == 5:
                    count = all_review[review].find_all('span', attrs = {'class':'_3WqoL'})[3].text
                elif len(all_review[review].find_all('span', attrs = {'class':'_3WqoL'})) == 6:
                    count = all_review[review].find_all('span', attrs = {'class':'_3WqoL'})[4].text
                else:
                    count = ""
                print('방문횟수 = '+count)
                count_list.append(count)                

                ## review 내용
                try: 
                    review_content = all_review[review].find('span', attrs = {'class':'WoYOw'}).text
                except: # 리뷰가 없다면
                    review_content = ""
                print('리뷰 내용 : '+review_content)
                review_list.append(review_content)                    

                print('\n\n')

        except Exception as total_review_err:
            none_review = "네이버 리뷰 0개"
            print(none_review)   


    except Exception as err:
        print(err)
        error_list = '{}행 에러 : {}'.format(i,err)
        error.append(error_list)
        rating_list.append(' ')
        avg_rating_list.append(' ')
        review_list.append(' ')

driver.quit()
# Out:
# ======================================================
# -더보기 버튼 모두 클릭 완료-
# 사업장명 :  1618248387
# 리뷰 총 개수 : 0
# ----------------------------------------------

# %%
# Out:
# ['299행 에러 : can only concatenate str (not "numpy.int64") to str']
